# 317216      5   19  05:39:19   Control
# 317217      5   19  05:37:59   Control
# 317218      5   19  05:37:45   Control
# 317219      5   19  05:37:13   Control
# 317220      5   13  15:33:04   Control
# 317221      5   13  15:32:43   Control
# 317222      5   13  15:31:09   Control
# 317223      5   13  15:31:04   Control
# 317224      5   13  15:30:47   Control
# 317225      5   20  23:07:09      Test
# 317226      5    6  23:51:05      Test
# 317227      5    6  23:50:40      Test
# 317228      5    6  23:43:47      Test
# 317229      5    6  23:43:34      Test
# 317230      5    6  23:43:27      Test
# 317231      5   10  22:57:17   Control
# 317232      5   10  22:56:31   Control
# 317233      5   10  22:56:23   Control
# 317234      5   10  22:56:20   Control

# %%
df.nunique()
# Out:
# Unnamed: 0      317235
# client_id        50500
# visitor_id       56011
# visit_id         69205
# process_step         5
# date_time       283344
# year                 1
# month                4
# day                 31
# time             69704
# Variation            2
# dtype: int64

# %%
df.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
df.head(3)
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time  year  month  day      time Variation
# 0  2017-04-17 15:27:07  2017      4   17  15:27:07      Test
# 1  2017-04-17 15:26:51  2017      4   17  15:26:51      Test
# 2  2017-04-17 15:19:22  2017      4   17  15:19:22      Test

# %%
df_steps = df.groupby(["client_id"])[["process_step"]].count()

# %%
df_steps
# Out:
#            process_step
# client_id
# 555                   5
# 647                   5
# 934                   4
# 1028                  9
# 1104                  2
# ...                 ...
# 9999150               3
# 9999400               5
# 9999626               2
# 9999729              11
# 9999832               2
#
# [50500 rows x 1 columns]

# %%
sns.countplot(data = df_steps, x='process_step', palette="Set3")
# Out:
# /var/folders/v4/fgnr7b6s2fdbdy6vyj585tz40000gn/T/ipykernel_2014/2183626455.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = df_steps, x='process_step', palette="Set3")
# <Axes: xlabel='process_step', ylabel='count'>

# %%
pivot_steps_clients = pd.pivot_table(df, values = "date_time" , index= ["visitor_id"] , columns = ["process_step"], aggfunc = "count", fill_value=0, margins = True, margins_name = 'Total')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pivot_steps_clients = pd.pivot_table(df, values = "date_time" , index= ["visitor_id"] , columns = ["process_step"], aggfunc = "count", fill_value=0, margins = True, margins_name = 'Total')
#
# NameError: name 'pd' is not defined

# %%
pivot_steps_clients #change the count of "date_time instead of variation"

# %%
new_order = ['start', 'step_1', 'step_2', 'step_3', 'confirm']

# Reordenar columnas
pivot_steps_clients  = pivot_steps_clients [new_order]

# %%
pivot_steps_clients.sort_values(by="confirm")  # it can be changed by any column...
# Out:
# process_step   start  step_1  step_2  step_3  confirm
# client_id
# 5025164            2       1       1       0        0
# 3303771            1       0       0       0        0
# 3303323            1       0       0       0        0
# 3302779            2       0       0       0        0
# 3302734            2       0       0       0        0
# ...              ...     ...     ...     ...      ...
# 8047921            6       5       5       7       17
# 1637369            0       0       0       0       17
# 8290360            1       1       0       0       17
# 465007            21      12      11       9       19
# Total         101153   68210   56672   48264    42936
#
# [50501 rows x 5 columns]

# %%
# Agregar total por columnas
pivot_steps_clients['Total'] = pivot_steps_clients.sum(axis=1)

# %%
pivot_steps_clients.sort_values(by="Total")
# Out:
# process_step   start  step_1  step_2  step_3  confirm   Total
# client_id
# 4151322            1       0       0       0        0       1
# 2372658            0       0       0       0        1       1
# 2372059            1       0       0       0        0       1
# 6671465            1       0       0       0        0       1
# 2370900            1       0       0       0        0       1
# ...              ...     ...     ...     ...      ...     ...
# 2313292            4      15      24      16        2      61
# 4167815           17      19      16       5        4      61
# 9638063           18      19      20      13        1      71
# 465007            21      12      11       9       19      72
# Total         101153   68210   56672   48264    42936  317235
#
# [50501 rows x 6 columns]

# %%
dt["process_step"].value_counts()  #take a look from here...
# Out:
# process_step
# start      55773
# step_1     38666
# step_2     30899
# step_3     25761
# confirm    25600
# Name: count, dtype: int64

# %%
pivot_steps_visit = pd.pivot_table(df, values = "date_time" , index= ["visit_id"] , columns = ["process_step"], aggfunc = "count", fill_value=0, margins = True, margins_name = 'Total')

# %%
pivot_steps_visit

# %%
new_order = ['start', 'step_1', 'step_2', 'step_3', 'confirm']

# Reordenar columnas
pivot_steps_visit  = pivot_steps_visit[new_order]

# %%
valid_visits = dt[dt["process_step"].isin(new_order)]
valid_visits.shape

# %%
pivot_steps_visit

# %%
pivot_steps_visit['Total'] = pivot_steps_visit.sum(axis=1)

# %%
pivot_steps_visit

# %%
rows_start_zero = (pivot_steps_visit["start"] == 0)
rows_start_zero

# %%
piv_steps_total = pivot_steps_visit.drop(pivot_steps_visit[rows_start_zero].index)

# %%
piv_steps_total

# %%
total_users = len(piv_steps_total["confirm"])
total_users

# %%
# Identificar filas que contienen al menos un valor igual a cero
rows_with_zero = (pivot_steps_visit == 0).any(axis=1)
rows_with_zero

# %%
# Eliminar esas filas
piv_steps = pivot_steps_visit.drop(pivot_steps_visit[rows_with_zero].index)

piv_steps  #17846 rows × 6 columns:  17846 TOTAL USERS WITH "CONFIRM" AND NO empty ROWS IN OTHER STEPS

# %%
confirm = len(piv_steps["confirm"])
confirm

# %%
completion_test = round((confirm/total_users)*100,2)

# %%
completion_test

# %%
# MISSING HERE: CALCULATE THE SAME FOR CONTROL GROUP AND CLEAN THIS FILE FOR LAST VERSION, ERASE WHAT WE DON'T NEED!

# %%
pivot_steps_visit.confirm.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 pivot_steps_visit.confirm.unique()
#
# NameError: name 'pivot_steps_visit' is not defined

# %%
len(pivot_steps_visit[pivot_steps_visit["confirm"] != 0 & pivot_steps_visit["confirm"] >= 5].values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/v4/fgnr7b6s2fdbdy6vyj585tz40000gn/T/ipykernel_22855/2396578548.py in ?()
# ----> 1 len(pivot_steps_visit[pivot_steps_visit["confirm"] != 0 & pivot_steps_visit["confirm"] >= 5].values)
#
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(
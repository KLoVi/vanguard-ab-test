# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/KLoVi/vanguard-ab-test/main/Datasets_cleaned/merged_dataframeSF_gendr2.csv")

# %%
df
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age    gendr  \
# 0         836976        6.083333              73.0      60.5  Unknown
# 1        2304905        7.833333              94.0      58.0  Unknown
# 2        1439522        5.333333              64.0      32.0  Unknown
# 3        1562045       16.500000             198.0      49.0     Male
# 4        5126305       12.083333             145.0      33.0   Female
# ...          ...             ...               ...       ...      ...
# 50482    1780858       21.833333             262.0      68.5     Male
# 50483    6967120       21.666667             260.0      68.5     Male
# 50484    5826160       20.750000             249.0      56.5   Female
# 50485    8739285       19.083333             229.0      69.5   Female
# 50486    7468138       18.500000             222.0      61.0   Female
#
#        num_accts         bal  calls_6_mnth  logons_6_mnth Variation age_group
# ...

# %%
df_merged =

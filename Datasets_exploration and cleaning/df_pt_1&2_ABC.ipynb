# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

pd.set_option('display.max_rows', 500)

# %matplotlib inline

# %%
url_1 = "https://raw.githubusercontent.com/KLoVi/vanguard-ab-test/main/Datasets_cleaned/df_pt1%26_merged.csv"

# %%
df_1 = pd.read_csv(url_1)

# %%
df_1
# Out:
#         Unnamed: 0  client_id             visitor_id  \
# 0                0    9988021   580560515_7732621733
# 1                1    9988021   580560515_7732621733
# 2                2    9988021   580560515_7732621733
# 3                3    9988021   580560515_7732621733
# 4                4    9988021   580560515_7732621733
# ...            ...        ...                    ...
# 744636      412259    9668240   388766751_9038881013
# 744637      412260    9668240   388766751_9038881013
# 744638      412261    9668240   388766751_9038881013
# 744639      412262    9668240   388766751_9038881013
# 744640      412263     674799  947159805_81558194550
#
#                             visit_id process_step            date_time  year  \
# 0       781255054_21935453173_531117       step_3  2017-04-17 15:27:07  2017
# 1       781255054_21935453173_531117       step_2  2017-04-17 15:26:51  2017
# 2       781255054_21935453173_531117       step_3  2017-04-17 15:19:22  2017
# ...

# %%
df_1.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
df_1
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 744636    9668240   388766751_9038881013   922267647_3096648104_968866
# 744637    9668240   388766751_9038881013   922267647_3096648104_968866
# 744638    9668240   388766751_9038881013   922267647_3096648104_968866
# 744639    9668240   388766751_9038881013   922267647_3096648104_968866
# 744640     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time  year  month  day      time
# ...

# %%
url_2 = "https://raw.githubusercontent.com/KLoVi/vanguard-ab-test/main/Datasets_cleaned/df_final_clients.csv"

# %%
df_2 = pd.read_csv(url_2)

# %%
df_2
# Out:
#        Unnamed: 0  client_id Variation
# 0               0    9988021      Test
# 1               1    8320017      Test
# 2               2    4033851   Control
# 3               3    1982004      Test
# 4               4    9294070   Control
# ...           ...        ...       ...
# 50495       50495     393005   Control
# 50496       50496    2908510   Control
# 50497       50497    7230446      Test
# 50498       50498    5230357      Test
# 50499       50499    6334360      Test
#
# [50500 rows x 3 columns]

# %%
df_2.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
df_2
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 50495     393005   Control
# 50496    2908510   Control
# 50497    7230446      Test
# 50498    5230357      Test
# 50499    6334360      Test
#
# [50500 rows x 2 columns]

# %%
df_merged = pd.merge(df_1 , df_2 , on = "client_id", how = "left")

# %%
df_merged
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 744636    9668240   388766751_9038881013   922267647_3096648104_968866
# 744637    9668240   388766751_9038881013   922267647_3096648104_968866
# 744638    9668240   388766751_9038881013   922267647_3096648104_968866
# 744639    9668240   388766751_9038881013   922267647_3096648104_968866
# 744640     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time  year  month  day      time Variation
# ...

# %%
df_merged.Variation.value_counts()
# Out:
# Variation
# Test       176699
# Control    140536
# Name: count, dtype: int64

# %%
df_merged.Variation.isnull().sum() #427,406 null values, to drop!
# Out:
# 427406

# %%
df_AB = df_merged.dropna(subset=['Variation'])

# %%
df_AB.shape
# Out:
# (317235, 10)

# %%
df_AB.nunique()
# Out:
# client_id        50500
# visitor_id       56011
# visit_id         69205
# process_step         5
# date_time       283344
# year                 1
# month                4
# day                 31
# time             69704
# Variation            2
# dtype: int64

# %%
url_3 = "https://raw.githubusercontent.com/KLoVi/vanguard-ab-test/main/Datasets_cleaned/df_ABC_demo.csv"

# %%
df_3 = pd.read_csv(url_3)

# %%
df_3
# Out:
#        Unnamed: 0  client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age  \
# 0               0     836976             6.0              73.0      60.5
# 1               1    2304905             7.0              94.0      58.0
# 2               2    1439522             5.0              64.0      32.0
# 3               3    1562045            16.0             198.0      49.0
# 4               4    5126305            12.0             145.0      33.0
# ...           ...        ...             ...               ...       ...
# 70604       70604    7993686             4.0              56.0      38.5
# 70605       70605    8981690            12.0             148.0      31.0
# 70606       70606     333913            16.0             198.0      61.5
# 70607       70607    1573142            21.0             255.0      68.0
# 70608       70608    5602139            21.0             254.0      59.5
#
#       gendr  num_accts         bal  calls_6_mnth  logons_6_mnth
# ...

# %%
df_3.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
df_3
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...
